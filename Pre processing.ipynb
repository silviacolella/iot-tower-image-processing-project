# %% [markdown]
# # Pre processing images #

# %%
import cv2
import glob
import numpy as np

# %%
X_data = []
files = glob.glob ("/home/scolella/Downloads/CMFD/00000/*.jpg")

for myFile in files:
    print(myFile)
    image = cv2.imread (myFile)
    X_data.append (image)
# Out:
# /home/scolella/Downloads/CMFD/00000/00540_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00419_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00730_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00516_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00773_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00542_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00647_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00110_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00220_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00267_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00903_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00545_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00919_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00415_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00922_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00550_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00841_Mask.jpg
# /home/scolella/Downloads/CMFD/00000/00721_Mask.jpg
# ...

# %%
print('X_data shape:', np.array(X_data).shape)
